# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhina000/Linear_Regression_ML/blob/main/Polynomial_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Position_Salaries.csv')
x = dataset.iloc[:,1:-1].values
y = dataset.iloc[:,-1].values

# %% [markdown]
# # Training the polynomial regression model with whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 4)
x_poly = poly_reg.fit_transform(x)
regressor = LinearRegression()
regressor.fit(x_poly,y)
y_pred = regressor.predict(x_poly)

# %%
plt.scatter(x,y,color = 'red')
plt.plot(x,y_pred,color = 'blue')
plt.title('Real or Fake salary (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %%
regressor.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.45265155])
